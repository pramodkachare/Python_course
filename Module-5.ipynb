# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.0'

# %%
df = pd.read_csv('C:\\Users\\admin\\Desktop\\Pramod\\Python_course\\Iris.csv', header=0, index_col=0, skiprows=0)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              NaN           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# SYNTAX:
#     df.head()
#     -> Print first 5 entries in dataframe
#
#     df.head(10)
#     -> Print first 10 entries in dataframe
#
#     df.tail()
#     -> Print last 5 entries
#
#     df.tail(10)
#     -> Print last 10 entries

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail(8)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   3            147 non-null    int64
#  1   4.7          147 non-null    float64
#  2   3.2          147 non-null    float64
#  3   1.3          147 non-null    float64
#  4   0.2          147 non-null    float64
#  5   Iris-setosa  147 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.0+ KB

# %%
df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# #### Dataframe is a table representation/organization of data.
# - Each column is represented by a *header*.
# - Each row is represented by a *index*.
# - To identify each data entry is Dataframe, we need corresponding column header and row index values.
#
# <img src='https://pandas.pydata.org/docs/_images/01_table_dataframe.svg'>

# %%
df['SepalWidthCm']
# Out:
# Id
# 1      3.5
# 2      3.0
# 3      3.2
# 4      3.1
# 5      3.6
#       ...
# 146    3.0
# 147    2.5
# 148    3.0
# 149    3.4
# 150    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
type(df['SepalWidthCm'])
# Out:
# pandas.core.series.Series

# %%
Data = {'Student': ['Pramod', 'Ritwik', 'Aadi'],
       'Maths' : [60, 90, 92],
       'Science': [76, 98, 95]}

student_data = pd.DataFrame(Data)

# %%
student_data
# Out:
#   Student  Maths  Science
# 0  Pramod     60       76
# 1  Ritwik     90       98
# 2    Aadi     92       95

# %% [markdown]
# ### Each column in a dataframe is data series.
#
# <img src='https://pandas.pydata.org/docs/_images/01_table_series.svg'>

# %%
student_data['Maths'], type(student_data['Maths'])
# Out:
# (0    60
#  1    90
#  2    92
#  Name: Maths, dtype: int64,
#  pandas.core.series.Series)

# %%
student_data['Maths'].max()
# Out:
# 92

# %%
student_data['Maths'].mean()
# Out:
# 80.66666666666667

# %%
student_data['Maths'].describe()
# Out:
# count     3.000000
# mean     80.666667
# std      17.925773
# min      60.000000
# 25%      75.000000
# 50%      90.000000
# 75%      91.000000
# max      92.000000
# Name: Maths, dtype: float64

# %%
student_data.min()
# Out:
# Student    Aadi
# Maths        60
# Science      76
# dtype: object

# %% [markdown]
# ### Slicing

# %%
student_data
# Out:
#   Student  Maths  Science
# 0  Pramod     60       76
# 1  Ritwik     90       98
# 2    Aadi     92       95

# %%
student_data.shape
# Out:
# (3, 3)

# %% [markdown]
# ##### Using only header based slicing will copy all rows into new DataFrame.

# %%
student_data['Maths']
# Out:
# 0    60
# 1    90
# 2    92
# Name: Maths, dtype: int64

# %%
df2 = student_data[['Maths', 'Student']]
df2
# Out:
#    Maths Student
# 0     60  Pramod
# 1     90  Ritwik
# 2     92    Aadi

# %%
df2.shape
# Out:
# (3, 2)

# %%
student_data[student_data['Maths']>=90]
# Out:
#   Student  Maths  Science
# 1  Ritwik     90       98
# 2    Aadi     92       95

# %% [markdown]
# SYNTAX
# ##### dataframe.loc[rowind (index), colind (header)]

# %%
student_data.loc[student_data['Maths']>=90, 'Student']
# Out:
# 1    Ritwik
# 2      Aadi
# Name: Student, dtype: object

# %%
student_data
# Out:
#   Student  Maths  Science
# 0  Pramod     60       76
# 1  Ritwik     90       98
# 2    Aadi     92       95

# %% [markdown]
# SYNTAX
#     dataFrame.iloc[range_of_row_index(s), range_of_col_index(s)]
#
#     df.iloc[0, 0] -> select 0th row and 0th column
#     df.iloc[:5, 2] -> Select first 5 rows and 2nd column
#     df.iloc[2:5, 3:6] -> Select rows from 2 to 4 and columns from 3 to 5
#     df.iloc[-1, 3] -> select last row and 3rd column
#     df.iloc[:-4, -1] -> Slect all rows from 0 to except last 4 and last column

# %%
student_data.iloc[1, 1]
# Out:
# 90

# %%
student_data.iloc[0:2, :1]
# Out:
#   Student
# 0  Pramod
# 1  Ritwik

# %%
student_data.iloc[-1, 2]
# Out:
# 95

# %% [markdown]
# ### To file

# %%
df3 = student_data[student_data['Maths']>=90]
df3
# Out:
#   Student  Maths  Science
# 1  Ritwik     90       98
# 2    Aadi     92       95

# %% [markdown]
# SYNTAX
#     dataframe.to_csv(filename_with_extension, header=True(default)/False, index=True(default)/False)
#
#     -> Prints the data to a CSV file with given file name and heare and index are printed or exlcuded accordingly.

# %%
df3.to_csv('Math_topper.csv', header=True, index=False)

# %%
df3.to_excel('Math_topper.xlsx', header=True, index=False)

# %%
# ?df3.to_excel

# %% [markdown]
# ### Plotting using pandas

# %%
df = pd.read_csv('Iris.csv', header=0, index_col=0)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              NaN           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# Id
# 1            False         False          False         False    False
# 2             True         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# 5            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
# 150          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
df.notnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# Id
# 1             True          True           True          True     True
# 2            False          True           True          True     True
# 3             True          True           True          True     True
# 4             True          True           True          True     True
# 5             True          True           True          True     True
# ..             ...           ...            ...           ...      ...
# 146           True          True           True          True     True
# 147           True          True           True          True     True
# 148           True          True           True          True     True
# 149           True          True           True          True     True
# 150           True          True           True          True     True
#
# [150 rows x 5 columns]

# %%
df.isna()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# Id
# 1            False         False          False         False    False
# 2             True         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# 5            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
# 150          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
SYNTAX:
    dataframe.dropna(axis, how)
    
    axis = 0 or 1 or 'index' or 'columns'
    how = {'any', 'all'}
    
    e.g. dataframe.dropna(axis=0, how='any')
        -> If any value in a row is missing then delete the complete row
        
        dataframe.dropna(axis=1, how='any')
        -> If any value in a column is missing then delete the complete column
        
        dataframe.dropna(axis=0, how='all')
        -> If all values in a row are missing then delete the complete row

# %%
df.dropna(axis=0, how='any')
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# 6              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.dropna(axis=1, how='any')
# Out:
#      SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1             3.5            1.4           0.2     Iris-setosa
# 2             3.0            1.4           0.2     Iris-setosa
# 3             3.2            1.3           0.2     Iris-setosa
# 4             3.1            1.5           0.2     Iris-setosa
# 5             3.6            1.4           0.2     Iris-setosa
# ..            ...            ...           ...             ...
# 146           3.0            5.2           2.3  Iris-virginica
# 147           2.5            5.0           1.9  Iris-virginica
# 148           3.0            5.2           2.0  Iris-virginica
# 149           3.4            5.4           2.3  Iris-virginica
# 150           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
df.dropna(axis=0, how='all')
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              NaN           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.dropna(axis=0, how='any', inplace=True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# 6              5.4           3.9            1.7           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.fillna(0, axis=0, inplace=True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              0.0           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.replace(to_replace='Iris-setosa', value='Setosa', inplace=True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2          Setosa
# 2              0.0           3.0            1.4           0.2          Setosa
# 3              4.7           3.2            1.3           0.2          Setosa
# 4              4.6           3.1            1.5           0.2          Setosa
# 5              5.0           3.6            1.4           0.2          Setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
var = {'Iris-setosa': 'Setosa', 'Iris-virginica': 'Virginica'}
df.replace(var, inplace=True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# Id
# 1              5.1           3.5            1.4           0.2     Setosa
# 2              0.0           3.0            1.4           0.2     Setosa
# 3              4.7           3.2            1.3           0.2     Setosa
# 4              4.6           3.1            1.5           0.2     Setosa
# 5              5.0           3.6            1.4           0.2     Setosa
# ..             ...           ...            ...           ...        ...
# 146            6.7           3.0            5.2           2.3  Virginica
# 147            6.3           2.5            5.0           1.9  Virginica
# 148            6.5           3.0            5.2           2.0  Virginica
# 149            6.2           3.4            5.4           2.3  Virginica
# 150            5.9           3.0            5.1           1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.interpolate('linear', axis=0)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot()

# %%
df[['SepalLengthCm', 'SepalWidthCm']].plot()

# %%
df[['SepalLengthCm', 'SepalWidthCm']].plot.bar()

# %%
df[['SepalLengthCm', 'SepalWidthCm']].plot.pie(figsize = (10, 10), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002C85E6B3848>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002C85E696D88>],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(15, 10))

df['SepalLengthCm'].plot.pie(ax=ax)
fig.savefig('SepalLengthCm.png')

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
a = [0, 2, np.NaN, 3, 4, 5]

plt.plot(a)
