# %% [markdown]
# ## Classes and Objects

# %% [markdown]
# CLass: user-defined structure or prototype
#     e.g. car, bike
#
# Object: it is an instance of a class; specialized user-defined structure
#     e.g. Hond civic, Hero Splender
#
# Attribute: it is a characteristic of class
#     e.g transmission (manual/auto), sedan/hatchback, rear AC, etc.
#
# Methods: it is an action of the class (may/may not modify the class attributes)

# %% [markdown]
# SYNTAX:
#     class classname:
#         # contents: attributes and methods pf class

# %%
class myfirstclass:
    x = 5

# %% [markdown]
# ## Class instance -> Object

# %%
c1 = myfirbstclass()
print(c1)
# Out:
# <__main__.myfirstclass object at 0x000001365058B288>

# %% [markdown]
# ### attribute of a class can be accessed using 'dot' operator on object of the class.

# %%
c1.x
# Out:
# 5

# %%
c1.x = 10
c1.x
# Out:
# 10

# %%
c2 = myfirstclass()

# %%
c2.x
c1.x = c1.x + 5

c1.x, c2.x
# Out:
# (15, 5)

# %%
class mysecondclass:
    x = 5
    y = 10
    
    def show(self):
        print('Hi')

# %%
c3 = mysecondclass()

# %%
c3.x, c3.y
# Out:
# (5, 10)

# %%
c3.show()
# Out:
# Hi

# %%
c1.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1e0806c76781> in <module>
# ----> 1 c1.show()
#
# AttributeError: 'myfirstclass' object has no attribute 'show'

# %%
class mythirdclass:
    x = 5
    y = 10
    
    def show(self):
        print(self.x)
        print(self.get_x())
        
    def get_x(self):
        return self.x

# %%
c5 = mythirdclass()

# %%
c5.x, c5.y
# Out:
# (5, 10)

# %%
c5.show()
# Out:
# 5
# 5

# %%
class student:
    name = 'Pramod'
    gender = 'M'
    maths = 90
    science = 95

# %%
pr = student()
pr.name, pr.gender, pr.maths, pr.science
# Out:
# ('Pramod', 'M', 90, 95)

# %%
rw = student()
rw.name, rw.gender, rw.maths, rw.science
# Out:
# ('Pramod', 'M', 90, 95)

# %%
rw = student()
rw.name = 'Ritwik' 
rw.gender='M'
rw.maths = 95 
rw.science = 99

# %%
rw.name, rw.gender, rw.maths, rw.science
# Out:
# ('Ritwik', 'M', 95, 99)

# %% [markdown]
# ### --init-- method

# %% [markdown]
# It is a constructor. It defined initial values of each attributed of that particular class

# %%
class student:
    name = 'Pramod'
    
    def __init__(self, name):
        self.name = name

# %%
ad = student('Aadi')
ad.name
# Out:
# 'Aadi'

# %%
class student:
    name = ''
    gender = ''
    maths = 0
    science = 0
    
    def __init__(self, name, gen, a, b):
        self.name = name
        self.gender = gen
        self.maths = a
        self.science = b

# %%
pr = student('Pramod', 'M', 85, 91)

# %%
pr.name, pr.gender, pr.maths, pr.science
# Out:
# ('Pramod', 'M', 85, 91)

# %%
rw = student('Ritwik', 'M', 95, 96)
ad = student('Aadi', 'M', 96, 95)

# %%
rw.name, rw.gender, rw.maths, rw.science
# Out:
# ('Ritwik', 'M', 95, 96)

# %%
ad.name, ad.gender, ad.maths, ad.science
# Out:
# ('Aadi', 'M', 96, 95)

# %%
datas = [['Pramod', 'M', 95, 90], ['Ritwik', 'M', 85, 99], ['Aadi', 'M', 99, 80]]
datas
# Out:
# [['Pramod', 'M', 95, 90], ['Ritwik', 'M', 85, 99], ['Aadi', 'M', 99, 80]]

# %%
x = []
for data in datas:
    x.append(student(data[0], data[1], data[2], data[3]))

# %%
x
# Out:
# [<__main__.student at 0x136545f49c8>,
#  <__main__.student at 0x136545f4b48>,
#  <__main__.student at 0x136545f4408>]

# %%
x[0].name, x[1].name, x[2].name
# Out:
# ('Pramod', 'Ritwik', 'Aadi')

# %%
x[0].maths, x[1].maths, x[2].maths
# Out:
# (95, 85, 99)

# %%
class student:   
    def __init__(self, name, gen='M', a=0, b=0):
        self.name = name
        self.gender = gen
        self.maths = a
        self.science = b
        
    def up_math(self):
        print('Math marks are increased by 5.')
        self.maths += 5
#         return self.maths+5   #

# %%
pr = student('Pramod', 'M', 80, 45)

# %%
pr.name, pr.gender, pr.maths, pr.science
# Out:
# ('Pramod', 'M', 80, 45)

# %%
pr.up_math()
# Out:
# Math marks are increased by 5.
# 85

# %%
pr.maths
# Out:
# 80

# %%
## Additing a new attribute with value is allowed. (without value calling an unknnown attribute is not allowed.)

# %%
pr.history = 60

# %%
pr.history
# Out:
# 60

# %%
pr.geo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11532/182670684.py in <module>
# ----> 1 pr.geo
#
# AttributeError: 'student' object has no attribute 'geo'

# %%
class student:   
    def __init__(first, name, gen='M', a=-1, b=0):
        first.name = name
        first.gender = gen
        first.maths = a
        first.science = b
        
    def up_math(first):
        print('Math marks are increased by 5.')
        first.maths += 5
#         return self.maths+5   #

# %%
pr = student('Pramod', 'M', 80, 45)

# %%
pr.up_math()
# Out:
# Math marks are increased by 5.

# %%
pr.maths
# Out:
# 85

# %%
pr.science += 20

# %%
pr.science
# Out:
# 65

# %%
del pr.maths

# %%
pr.maths
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11532/4009120193.py in <module>
# ----> 1 pr.maths
#
# AttributeError: 'student' object has no attribute 'maths'

# %%
rw = student('Ritwik')

# %%
rw.maths
# Out:
# 0

# %%
del pr

# %%
pr.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11532/3317473751.py in <module>
# ----> 1 pr.name
#
# NameError: name 'pr' is not defined

# %% [markdown]
# ## Inheritence

# %%
class Parent:
    a
    b
    c
    
    def f1
    
    def f2
    
class child(Parent):
    ---------------------------------------
    a
    b
    c
    
    def f1
    def f2b
    ---------------------------------------
    d
    e
    f
    
    def f3
    
    def f4

# %%
class Human:
    def __init__(self, first='A', last='B'):
        self.firstname = first
        self.lastname = last
    
    def print_name(self):
        print(self.firstname, self.lastname)

# %%
h = Human()
h.firstname, h.lastname
# Out:
# ('A', 'B')

# %%
class student(Human):
    def __init__(self, f, l):
        Human.__init__(self, f, l)

# %%
s = student('Pramod', 'Kachare')

# %%
s.firstname, s.lastname
# Out:
# ('Pramod', 'Kachare')

# %%
class student(Human):
    def __init__(self, f, l, a=-1):
        super().__init__(f, l)
        super().print_name()
        self.maths = a
    
    def print_maths(self):
        print('Math marks: ', self.maths)

# %%
s = student('Pramod', 'Kachare')
# s.firstname, s.lastname, 
s.maths
# Out:
# Pramod Kachare
# -1

# %%
h = Human()
h.maths
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11532/1720485043.py in <module>
#       1 h = Human()
# ----> 2 h.maths
#
# AttributeError: 'Human' object has no attribute 'maths'

# %%
s.print_maths(), s.
# Out:
# Math marks:  -1

# %%
class student(Human):
    def __init__(self, f, l, a=-1, h=-1):
        super().__init__(f, l)
        super().print_name()
        self.maths = a
        self.__history = h
    
    def print_maths(self):
        print('Math marks: ', self.maths)
        print('History marks: ', self.__history)

# %%
s1 = student('Pramod', 'Kachare', 80, 85)
# Out:
# Pramod Kachare

# %%
s1.__history
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-525ab7846fdb> in <module>
# ----> 1 s1.__history
#
# AttributeError: 'student' object has no attribute '__history'

# %%
s1._science = 50

# %%
s1._science
# Out:
# 50

# %%
s1._student__history
# Out:
# 85

# %%
class Human:
    def __init__(self, first='A', last='B'):
        self.firstname = first
        self.__lastname = last
    
    def print_name(self):
        print(self.firstname, self.__lastname)

# %%
class student(Human):
    def __init__(self, f, l, a=-1, h=-1):
        super().__init__(f, l)
        super().print_name()
        self.maths = a
        self.__history = h
    
    def print_maths(self):
        print('Math marks: ', self.maths)
        print('History marks: ', self.__history)

# %%
s2 = student('Pramod', 'Kachare', 80, 85)
# Out:
# Pramod Kachare

# %%
s2.__lastname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-fe84c302ecbf> in <module>
# ----> 1 s2.__lastname
#
# AttributeError: 'student' object has no attribute '__lastname'

# %%
s2._Human__lastname
# Out:
# 'Kachare'

# %%
s2._student__history
# Out:
# 85

# %% [markdown]
# ## Getters/setters

# %%
class Human:
    def __init__(self, first='A', last='B'):
        self.firstname = first
        self.lastname = last
    
    def setFirstName(self, name):
        self.firstname = name
        
    def setLastName(self, name):
        self.lastname = name
    
    def getFirstName(self):
        return self.firstname
    
    def getLastName(self):
        return self.lastname
    
    def print_name(self):
        print(self.getFirstName(), self.getLastName())

# %%
h1 = Human('Pramod', 'Kachare')

# %%
h1.getFirstName()
# Out:
# 'Pramod'

# %%
h1.getLastName()
# Out:
# 'Kachare'

# %%
h1.print_name()
# Out:
# Pramod Kachare

# %%
h1.setFirstName('Ritwik')
h1.setLastName('Naik')

# %%
h1.getFirstName(), h1.getLastName()
# Out:
# ('Ritwik', 'Naik')

# %% [markdown]
# ## \_\_str__

# %%
class student(Human):
    def __init__(self, f, l, a=-1, h=-1):
        super().__init__(f, l)
        super().print_name()
        self.maths = a
        self.__history = h
    
    def __str__(self):
        return 'This is object for '+ self.getFirstName()+ ' '+ self.getLastName()+'.'
    
    def getMaths(self):
        return self.maths
    
    def getHistory(self):
        return self.__history
    
    def setMaths(self, m):
        self.maths = m
        
    def setHistory(self, h):
        self.__history = h
    
    def print_maths(self):
        print('Math marks: ', self.maths)
        print('History marks: ', self.__history)

# %%
s3 = student('Pramod', 'Kachare', 60, 70)
# Out:
# Pramod Kachare

# %%
s3.getLastName()
# Out:
# 'Kachare'

# %%
s3.getMaths()
# Out:
# 60

# %%
print(s3)
# Out:
# This is object for Pramod Kachare.

# %%
class topper(student):
    def __init__(self, f, l, a=-1, h=-1):
        super().__init__(f, l, a, h)

# %%
t1 = topper('Pramod', 'Kachare', 90, 98)
# Out:
# Pramod Kachare

# %%
t1.getFirstName(), t1.getLastName()
# Out:
# ('Pramod', 'Kachare')

# %%
t1.getMaths(), t1.getHistory()
# Out:
# (90, 98)

# %%
class c1:
    def __init__(self):
        self.a = 2
        self.b = 4
        
class c2:
    def __init__(self):
        self.c = 6
        self.d = 8

class C3(c2, c1):
    def __init__(self):
        super().__init__()

# %%
x = C3()

# %%
x.a, x.b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-ee5dd97046fa> in <module>
# ----> 1 x.a, x.b
#
# AttributeError: 'C3' object has no attribute 'a'

# %%
x.c, x.d
# Out:
# (6, 8)

# %%
class c1:
    def __init__(self):
        self.a = 2
        self.b = 4
    
    def print_c1(self):
        print('C1 class')
        
class c2:
    def __init__(self):
        self.c = 6
        self.d = 8

class C3(c2, c1):
    def __init__(self):
        c1.__init__(self)
        c2.__init__(self)

# %%
x2 = C3()

# %%
x2.a, x2.b, x2.c, x2.d
# Out:
# (2, 4, 6, 8)

# %%
x2.print_c1()
# Out:
# C1 class

# %% [markdown]
# ## Polymorphism

# %%
class c1:
    def __init__(self):
        self.a = 2
        self.b = 4
    
    def print_c(self):
        print('C1 class')
        
class c2:
    def __init__(self):
        self.c = 6
        self.d = 8

class C3(c1):
    def __init__(self):
        super().__init__()
        
    def print_c(self):
        super().print_c()
        print('C3 class')

# %%
x3 = C3()
x3.print_c()
# Out:
# C1 class
# C3 class

# %%
x4 = c1()
x4.print_c()
# Out:
# C1 class

# %%
class c1:
    def __init__(self):
        self.a = 2
        self.b = 4
    
    def print_c(self):
        print('C1 class')
        
class c2:
    def __init__(self):
        self.c = 6
        self.d = 8

    def print_c(self):
        print('C2 class')
        
class C3(c1, c2):
    def __init__(self):
        c1.__init__(self)
        c2.__init__(self)
        self.e = 10
        
    def print_c(self):
        c1.print_c(self)
        c2.print_c(self)
        print('C3 class')

# %%
x5 = C3()
x5.print_c()
# Out:
# C1 class
# C2 class
# C3 class

# %% [markdown]
# ## Ierators

# %%
name = 'Pramod'

N = iter(name)

# %%
print(N)
# Out:
# <str_iterator object at 0x000001D60B39A788>

# %%
next(N)
# Out:
# 'P'

# %%
next(N)
# Out:
# 'r'

# %%
next(N)
# Out:
# 'a'

# %%
next(N), next(N), next(N)
# Out:
# ('m', 'o', 'd')

# %%
next(N)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-55-0f4723c98d79> in <module>
# ----> 1 next(N)
#
# StopIteration:

# %%
A = [10, 20, 30, 40, 50, 60]
itr = iter(A)

# %%
print(itr)
# Out:
# <list_iterator object at 0x000001D60D287C88>

# %%
next(itr)
# Out:
# 10

# %%
next(itr), next(itr), next(itr), next(itr)
# Out:
# (20, 30, 40, 50)

# %% [markdown]
# ## Generator

# %%
def natural_num():
    n = 1
    while n <=11:
        yield n
        n += 1

# %%
print(natural_num())
# Out:
# <generator object natural_num at 0x000001D60D1BF348>

# %%
nat_num = natural_num()

# %%
next(nat_num), next(nat_num), next(nat_num), next(nat_num), next(nat_num)
# Out:
# (1, 2, 3, 4, 5)

# %%
next(nat_num), next(nat_num), next(nat_num), next(nat_num), next(nat_num)
# Out:
# (6, 7, 8, 9, 10)

# %%
next(nat_num)
# Out:
# 11

# %%
next(nat_num)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-74-5425f96b6fc9> in <module>
# ----> 1 next(nat_num)
#
# StopIteration:
